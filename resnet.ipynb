# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input, decode_predictions

# %%
import numpy as np

# %%
import cv2

# %%
model = ResNet50(weights='imagenet')

# %%
import matplotlib.pyplot as plt

# %%
def classify(img):
  img = preprocess_input(img)
  preds = model.predict(np.array([img]))
  results = decode_predictions(preds, top=1)[0]
  decode_predictions(preds, top=1)
  return results

# %%
img = cv2.imread('/content/cat1.jpg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(img)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 1s 918ms/step
# Persian_cat : 0.9780829

# %%
img = cv2.imread('/content/cat2.jpg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(img)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Siamese_cat : 0.31397796

# %%
img = cv2.imread('/content/dog1.jpg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(img)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Maltese_dog : 0.83670413

# %%
img = cv2.imread('/content/dog2.jpg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(img)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Pomeranian : 0.74549127
